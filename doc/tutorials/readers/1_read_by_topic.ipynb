# %% [markdown]
# # Read Messages by Topic
#
# This tutorial uses the `TopicMessageReader` to read messages from a robolog by topic. It's one of several reader types available, each designed for different use cases.

# %%
import os
from pathlib import Path

current_dir = Path.cwd()
project_root = None

while current_dir != current_dir.parent:
    if (current_dir / '.git').exists():
        project_root = current_dir
        break
    current_dir = current_dir.parent

os.chdir(project_root)

# %% [markdown]
# A `TopicMessageReader` can be created by using the factory function `make_topic_message_reader`.

# %%
from src.reader import factory

reader = factory.make_topic_message_reader("doc/tutorials/data/ros2")

# %% [markdown]
# These are the available topics to read from.

# %%
reader.topics
# Out:
# ['/fluid_pressure', '/rosout', '/parameter_events', '/events/write_split']

# %% [markdown]
# This example reads messages from two topics and casts them into a pandas DataFrame. The resulting table contains four columns:
#
# - `robolog_id`: A unique ID generated for this robolog.
# - `timestamp_seconds`: The timestamp of each message in seconds.
# - `/rosout` and `/fluid_pressure`: The actual message content for each topic.
#
# The `None` values appear in the topic columns because the message timestamps are not perfectly aligned between the different topics. This will be covered in more detail later.

# %%
dataset = reader.read(["/rosout", "/fluid_pressure"])

dataset.to_table().to_pandas()
# Out:
#                               robolog_id  timestamp_seconds  \
# 0   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 1   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 2   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 3   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 4   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 5   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 6   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 7   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 8   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 9   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 10  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 11  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 12  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 13  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
#
#                                               /rosout  \
# 0   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 1   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 2   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 3   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 4   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 5   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 6   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
#
#                                       /fluid_pressure
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 8   {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 9   {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 10  {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 11  {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 12  {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 13  {'header': {'stamp': {'sec': 0, 'nanosec': 0},...

# %% [markdown]
# The reader also supports filtering messages by a specific time range.

# %%
dataset = reader.read(
    ["/rosout", "/fluid_pressure"],
    start_seconds=1689969665.5,
    end_seconds=1689969666.5,
)

dataset.to_table().to_pandas()
# Out:
#                              robolog_id  timestamp_seconds  \
# 0  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 1  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
#
#                                              /rosout  \
# 0  {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 1                                               None
#
#                                      /fluid_pressure
# 0                                               None
# 1  {'header': {'stamp': {'sec': 0, 'nanosec': 0},...

# %% [markdown]
# To handle the `None` values caused by misaligned timestamps, set `ffill=True`.
#
# This applies a **forward fill**, which propagates the last valid message forward to fill any gaps until the next message arrives. This technique is also known as "last observation carried forward" (LOCF).

# %%
dataset = reader.read(["/rosout", "/fluid_pressure"], ffill=True)

dataset.to_table().to_pandas()
# Out:
#                               robolog_id  timestamp_seconds  \
# 0   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 1   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 2   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 3   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 4   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 5   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 6   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 7   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 8   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 9   281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 10  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 11  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 12  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
# 13  281e260f-0fc9-57e6-8c33-787dc436009f       1.689970e+09
#
#                                               /rosout  \
# 0   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 1   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 2   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 3   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 4   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 5   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 6   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 7   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 8   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 9   {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 10  {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 11  {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 12  {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
# 13  {'DEBUG': 10, 'INFO': 20, 'WARN': 30, 'ERROR':...
#
#                                       /fluid_pressure
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 8   {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 9   {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 10  {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 11  {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 12  {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
# 13  {'header': {'stamp': {'sec': 0, 'nanosec': 0},...
